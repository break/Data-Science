# %% [raw]
# <script>
#   function code_toggle() {
#     if (code_shown){
#       $('div.input').hide('500');
#       $('#toggleButton').val('Show Code')
#     } else {
#       $('div.input').show('500');
#       $('#toggleButton').val('Hide Code')
#     }
#     code_shown = !code_shown
#   }
#
#   $( document ).ready(function(){
#     code_shown=false;
#     $('div.input').hide()
#   });
# </script>
# <form action="javascript:code_toggle()"><input type="submit" id="toggleButton" value="Show Code"></form>

# %%
# %%HTML
# <head>
# <meta name="viewport" content="width=device-width, initial-scale=1">
#     <style>
#     body {background-color:#ffffff;background-repeat:no-repeat;background-position:top left;background-attachment:fixed;}
#     h1{text-align:center;font-family:Helvetica, sans-serif;color:#00000;background-color:#FFFFFF;}
#     h2{text-align:center;font-family:Helvetica, serif;font-size:15px;font-style:normal;font-weight:normal;color:#000000;background-color:#FFFFFF;}
#     h3{text-align:left;font-family:Helvetica, sans-serif;color:#000000;background-color:#FFFFFF;}
#     p {text-align:left;font-family:Helvetica, serif;font-size:15px;font-style:normal;font-weight:normal;color:#000000;background-color:#FFFFFF;}
#     </style>
# </head>
# <body>
#     <h1>The Connectome of Our Behavior</h1>
#     <h2>Shreya Bajpai</h2>
#     <p><img src="http://www.extremetech.com/wp-content/uploads/2016/01/connectome.jpg" style="max-width:50%;margin-left: auto; margin-right: auto;"></p>
#     <h3>A Connect...Connectome? What's that?</h3>
#     <p></p>
#         <p> The term 'connectome' is a seemingly complicated idea of unraveling the wiring of a brain to map the
#        numerous connections that exist in a bran. This term was introduced in a 2005 paper, <a href="http://journals.plos.org/ploscompbiol/article?id=10.1371/journal.pcbi.0010042">The human connectome: a structural description of the human brain</a>, where the researchers (Sporns, Tononi, & Kötter) defined it as, "the connection matrix of the human (or any other animal's) brain represents an indispensable foundation for basic and applied neurobiological research." Neuroscience aims to increase our understanding of how the connections in our brain affect our behavior, both in normal and abnormal situations. Not only would this increase our understanding of the patterns of alleged behavior in humans, it could better aid the development of artificial intelligence. </p>
#     <p></p>
#         <p>An organization, the <a href="https://www.humanconnectome.org">Connectome Coordination Facility</a> (CCF), researches how age, disease, growth, and other variable
#        factors can influence the malleable connections in the human brain. A rat neurome (connectome) mapping the 7000+
#        connections in a rat brain currently exists (thanks to <a href="https://www.researchgate.net/publication/47794330_INAUGURAL_ARTICLE_by_a_Recently_Elected_Academy_MemberFoundational_model_of_structural_connectivity_in_the_nervous_system_with_a_schema_for_wiring_diagrams_connectome_and_basic_plan_architecture">Larry Swanson and Mihail Bota</a>'s hard work), but to map the connections in a human brain is a much, much larger feat. MRI measurements are the primary means of estimating the connections at a millimeter resolution. However, the size of data that is created by these measurements and the complexity of tracing the neural connections through the brain present a big data problem for us data scientists.
#     </p>
#     <h3>A Whirlwind of Data Collection</h3>
#     <p> The facility from which I collected data from is a compiler of many research studies that have looked at MRIs, everything from structural MRIs to function MRIs. They collect, compile, and distribute the data from an enormous amount of studies.
#         Gaining access to the data was no easy feat. I was instructed to sign up for an account as a student, then I had to wait a few business days for my account to be approved. Unknowingly, CCF installed an encryption application (Aspera Connect, Asper Encrypt) on my mac.
#         Upon approval, I was allowed to sign on to the subsidiary website that holds all the data called ConnectomeDB. I still did not have the data in my hands. I was interested in the Young Adult HCP dataset, which harbored a myriad of behavioral and functional reportings of over 1200 individuals, aged 25 to 35.
#         The data was obtained from many studies from the following universities: Washington University in Saint Louis, University of Minnesota, Oxford University Saint Louis University, Indiana University, University d’Annunzio, Ernst Strungmann Institute, Warwick University, Radboud University Nijmegen, Duke University.
#         At first, I could not access the data in its entirety so I requested to make an Amazon Web Services (AWS) account, a platform which would allow me to remotely access the data via AWS. I downloaded Cyberduck and signed in with the key and password given to me. Now began the endless days of parsing through the data
#         and discovering the complexities of analyzing GBs of data for a single individual. I realized this would be essentially futile, so I tried to make use of the software that ConnectomeDB had.
#
#         <p> The following are the tools I attempted to implement with the dataset: </p>
#
#         <p>(1) <span style="font-weight:bold">MR Pipeline</span> (a set of tools (primarily, but not exclusively, shell scripts) for processing MRI images for the Human Connectome Project. Among other things, these tools implement the Minimal Preprocessing Pipeline (MPP) described in Glasser et al. 2013.) </p>
#         <p> (2) <span style="font-weight:bold">MegConnectome</span> (analysis of MEG data in the Human Connectome Project is performed using FieldTrip, a MATLAB toolbox for MEG and EEG analysis, in combination with additional analysis scripts and functions that have specifically been written for the HCP.) </p>
#         <p> (3) <span style="font-weight:bold">FSL</span> is a comprehensive (structural, functional and diffusion) neuroimaging software platform. FSL tools will be used in a variety of contexts in the HCP, including preprocessing, diffusion analysis and tractography, R-fMRI ICA, and parcellation. </p>
#         <p> (4) <span style="font-weight:bold">Brain Connectivity Toolbox (BCT)</span> provides an access to a large selection of complex network measures in Matlab. Such measures aim to characterize brain connectivity by neurobiologically meaningful statistics, and are increasingly used in the description of structural and functional connectivity datasets</p>
#         <p> (5) <span style="font-weight:bold">Fieldtrip</span> is an open source Matlab toolbox for MEG, EEG and LFP analysis. It includes algorithms for simple and advanced analysis of electrophysiological data, such as time-locked averaging, time-frequency analysis, source reconstruction using dipoles, distributed sources and beamformers, channel and source-level synchronization estimates and non-parametric statistical testing. (Related: FieldTrip Workshop webex presentation).</p>
#         <p> These all proved to be too complicated for the task at hand. However, I had spent a majority of my time learning these and working with these. Nonetheless, I would not be deterred. I requested access to ConnectomeDB and realized I could download all 1200 entries in a .csv file. That would have been helpful earlier.
#             Next, I ran rudimentary analyses on Excel to see what data could stand out. I picked about 20-25 data columns and began to run analyses on them using Bokeh--a a Python interactive visualization library that targets web browsers, specifically. The analyses ran and took another large chunk of my time. However, I chose to feature the three I mention in the next section. I chose these because they seemed to be telling a story or supporting a story we
#             want to be telling. Unfortunately, a few days before the deadline, my Bokeh library began to break as I began to finalize the touches on my project. I had to then change my visualizations to utilize Pandas and Matplotlib. Though there were many hurdles along the way, I was able to learn so much more than I would have in a typical classroom setting. I even went on to work with HTML/CSS. <p><span style="font-weight:bold">Let's begin.</span></p>
#         </p>
#     </p>
#     <h3>Finding Meaning in the Data</h3>
#     <p> My first three In[]s involve working with the Pandas and ensuring an established connection between me and the server. I had done many more checks, but these seemed to tell the story the best. </p>
# </body>
# </html>
# Out:
# <head>
# <meta name="viewport" content="width=device-width, initial-scale=1">
#     <style>
#     body {background-color:#ffffff;background-repeat:no-repeat;background-position:top left;background-attachment:fixed;}
#     h1{text-align:center;font-family:Helvetica, sans-serif;color:#00000;background-color:#FFFFFF;}
#     h2{text-align:center;font-family:Helvetica, serif;font-size:15px;font-style:normal;font-weight:normal;color:#000000;background-color:#FFFFFF;}
#     h3{text-align:left;font-family:Helvetica, sans-serif;color:#000000;background-color:#FFFFFF;}
#     p {text-align:left;font-family:Helvetica, serif;font-size:15px;font-style:normal;font-weight:normal;color:#000000;background-color:#FFFFFF;}
#     </style>
# </head>
# <body>
#     <h1>The Connectome of Our Behavior</h1>
#     <h2>Shreya Bajpai</h2>
#     <p><img src="http://www.extremetech.com/wp-content/uploads/2016/01/connectome.jpg" style="max-width:50%;margin-left: auto; margin-right: auto;"></p>
# ...

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas

data = pandas.read_csv("Labeled Data.csv")

subjects = data.groupby('Age')
subjects.size()
# Out:
# Age
# 22-25    247
# 26-30    527
# 31-35    418
# 36+       14
# dtype: int64

# %%
# Visualize where we begin
data.head()
# Out:
#    Subject Release Acquisition Gender    Age  3T_Full_MR_Compl  T1_Count  \
# 0   104012    MEG2         Q07      F  26-30              True         1
# 1   105923    MEG2         Q07      F  31-35              True         2
# 2   111514    MEG2         Q02      M  31-35              True         2
# 3   146129    MEG2         Q08      M  22-25              True         2
# 4   153732    MEG2         Q07      F  26-30             False         1
#
#    T2_Count  3T_RS-fMRI_Count  3T_RS-fMRI_PctCompl     ...      NEORAW_60  \
# 0         2                 4                100.0     ...             SA
# 1         2                 4                100.0     ...              A
# 2         2                 4                100.0     ...              A
# 3         2                 4                100.0     ...             SA
# 4         1                 4                100.0     ...             SA
#
#    Noise_Comp  Odor_Unadj  Odor_AgeAdj  PainInterf_Tscore  Taste_Unadj  \
# ...

# %%
# This serves to show you the breadth of the data we have amassed.
data.tail()
# Out:
#       Subject Release Acquisition Gender    Age  3T_Full_MR_Compl  T1_Count  \
# 1201   972566    S900         Q11      F  31-35             False         1
# 1202   990366    S900         Q10      M  22-25              True         2
# 1203   992673    S900         Q12      F  31-35              True         1
# 1204   993675    S900         Q09      F  26-30              True         2
# 1205   996782    S900         Q08      F  26-30              True         2
#
#       T2_Count  3T_RS-fMRI_Count  3T_RS-fMRI_PctCompl     ...      NEORAW_60  \
# 1201         1                 2                 50.0     ...             SA
# 1202         1                 4                100.0     ...              A
# 1203         2                 4                100.0     ...              A
# 1204         2                 4                100.0     ...             SA
# 1205         2                 4                100.0     ...              A
#
# ...

# %%
# %%HTML
# <style>
#     body {background-color:#ffffff;background-repeat:no-repeat;background-position:top left;background-attachment:fixed;}
#     h2{text-align:center;font-family:Helvetica, serif;font-size:15px;font-style:normal;font-weight:normal;color:#000000;background-color:#FFFFFF;}
#     h3{text-align:left;font-family:Helvetica, sans-serif;color:#000000;background-color:#FFFFFF;}
#     p{text-align:left;font-family:Helvetica, serif;font-size:15px;font-style:normal;font-weight:normal;color:#000000;background-color:#FFFFFF;}
# </style>
# <h2> What's Important to Visualize </h2>
# <p> Now I attempt to highlight the 9 categories on which I found the data that could tell a story. I had to run analyses and comparsisons on 573 columns (a few were easily weeded out).</p>
# <p> Let's see what these categories mean: </p>
#       <p> The <span style="font-weight:bold">subject</span> indicates the symbolic number of the subject. </p>
#       <p> The <span style="font-weight:bold">release</span> indicates what study this subject was from. It was important to me to run analyses on normal, young adults, which is why I utilized S1200 subjects exclusively. </p>
#       <p> The <span style="font-weight:bold">Gender</span> and <span style="font-weight:bold">age</span> are self-explanatory. </p>
#       <p> The <span style="font-weight:bold">LifeSatisf_Unadj</span> is a subset within the Psychological Well-Being subdomain of Emotion. Life Satisfaction is your own cognitive evaluation of your life experiences and is concerned with whether people like their lives or not. Life satisfaction includes both general (e.g., my life is going well) and domain-specific (e.g., I am satisfied with my family life) aspects. This self-report measure for adults (ages 18 and above) is a 10-item calibrated scale comprised of items from the Satisfaction with Life Scale  and the Students' Life Satisfaction Scale.</p>
#       <p> The <span style="font-weight:bold">SelfEff_Unadj</span> is s a subset within the Stress & Self-Efficacy subdomain of Emotion. Self-Efficacy can be described as a person's belief in their capacity to manage their functioning and have control over meaningful events. This self-report measure for adults (ages 18 and above) is a CAT comprised of items modified from the General Self-Efficacy Scale (Schwarzer). It assesses respondents' sense of global self-efficacy.</p>
#       <p> The <span style="font-weight:bold">FS_L_Amygdala_Vol</span> is the Left-Amygdala Volume in a subject. </p>
#       <p> The <span style="font-weight:bold">MMSE_Score</span> is the Mini Mental State Examination, which attempts to gauge a subject's cognitive status or alertness.</p>
#       <p> The <span style="font-weight:bold">Gambling_Task_Median_RT_Smaller</span> is the median of the scores on the shorter task completed by subjects. </p>
#       <p> The <span style="font-weight:bold">PSQI_AmtSleep</span> is the amount of sleep that the subject received the night before the study in hours.
#       <p> These are the attributes that I chose to look into detail when beginning the visualizations. I chose these because they stood out as unique, and presented the information in a bite-sized, yet unabridged form. The fMRI data could be complexly presented, but that wouldn't entice everyone (it did entice me). These visualizations truly serve a story anyone can relate to. </p>
# Out:
# <style>
#     body {background-color:#ffffff;background-repeat:no-repeat;background-position:top left;background-attachment:fixed;}
#     h2{text-align:center;font-family:Helvetica, serif;font-size:15px;font-style:normal;font-weight:normal;color:#000000;background-color:#FFFFFF;}
#     h3{text-align:left;font-family:Helvetica, sans-serif;color:#000000;background-color:#FFFFFF;}
#     p{text-align:left;font-family:Helvetica, serif;font-size:15px;font-style:normal;font-weight:normal;color:#000000;background-color:#FFFFFF;}
# </style>
# <h2> What's Important to Visualize </h2>
# <p> Now I attempt to highlight the 9 categories on which I found the data that could tell a story. I had to run analyses and comparsisons on 573 columns (a few were easily weeded out).</p>
# <p> Let's see what these categories mean: </p>
#       <p> The <span style="font-weight:bold">subject</span> indicates the symbolic number of the subject. </p>
# ...

# %%
subjects = data[['Subject', 'Release', 'Gender', 'Age', 'LifeSatisf_Unadj', 'SelfEff_Unadj','FS_L_Amygdala_Vol','MMSE_Score','Gambling_Task_Median_RT_Smaller', 'PSQI_AmtSleep']]
test = subjects.sort_values(['Release', 'MMSE_Score'], ascending=True)
test.loc[subjects['Release'] == 'S1200']
# Out:
#      Subject Release Gender    Age  LifeSatisf_Unadj  SelfEff_Unadj  \
# 256   103212   S1200      M  31-35              60.3           50.8
# 264   116423   S1200      M  26-30              62.9           57.9
# 316   171128   S1200      F    36+              48.0           38.8
# 334   190940   S1200      M  31-35              49.2           44.4
# 368   274542   S1200      F  26-30              43.8           43.8
# 373   314225   S1200      M  22-25              52.6           44.5
# 389   392447   S1200      M  31-35              65.5           68.4
# 426   589567   S1200      M  22-25              67.6           55.5
# 449   760551   S1200      F  26-30              47.9           47.0
# 486   995174   S1200      M  22-25              38.9           44.8
# 267   118831   S1200      M  22-25              40.6           54.1
# 270   120414   S1200      F  26-30              51.1           43.6
# 276   126426   S1200      F  31-35              57.1           61.0
# ...

# %%
# %%HTML
# <style>
#     body {background-color:#ffffff;background-repeat:no-repeat;background-position:top left;background-attachment:fixed;}
#     h2{text-align:center;font-family:Helvetica, serif;font-size:15px;font-style:normal;font-weight:normal;color:#000000;background-color:#FFFFFF;}
#     h3{text-align:center;font-family:Helvetica, serif;font-size:15px;font-style:normal;font-weight:normal;color:#000000;background-color:#FFFFFF;}
#     p{text-align:left;font-family:Helvetica, serif;font-size:15px;font-style:normal;font-weight:normal;color:#000000;background-color:#FFFFFF;}
# </style>
# <h2> You Wouldn't Have Guessed It: Sleeping Might Affect Your Gambling Skills! </h2>
# <p> This one is for the gambling aficionados—the A.C. and Las Vegas lovers, listen up! </p>
# <p> Gambling is a fine art, they say (and I paraphrase). However, it is influenced by a variety of factors. Below you will observe that sleep is a key factor. Movies romanticize staying up all night and gambling; however, this might be reducing your odds of winning. On the other side of the coin, if casinos increase their players' alcohol consumption and delicious food intake, then they might save some big bucks. </p>
# <p> As you can see in the scatterplot below, besides the outliers, anything less than than 6-8 hours of sleep decreases (on median) the subjects' performance on a gambling task given in the study. We can see the clustering of 'good' scores in the middle of the chart (at the 6-8 hour range). </p>
# <p> A <span style="font-weight:bold">scatterplot</span> seemed to best fit the nature of this data. I wanted to showcase the large range of subjects' performance, and a bar graph or density plot could not do that well. In this scenario, you can see that the evidence speaks for itself, but for the non-believers, you have your outliers to support your sleepless gambling nights.
# <p> To increase your odds of winning, be sure to get a good night's rest! </p>
# Out:
# <style>
#     body {background-color:#ffffff;background-repeat:no-repeat;background-position:top left;background-attachment:fixed;}
#     h2{text-align:center;font-family:Helvetica, serif;font-size:15px;font-style:normal;font-weight:normal;color:#000000;background-color:#FFFFFF;}
#     h3{text-align:center;font-family:Helvetica, serif;font-size:15px;font-style:normal;font-weight:normal;color:#000000;background-color:#FFFFFF;}
#     p{text-align:left;font-family:Helvetica, serif;font-size:15px;font-style:normal;font-weight:normal;color:#000000;background-color:#FFFFFF;}
# </style>
# <h2> You Wouldn't Have Guessed It: Sleeping Might Affect Your Gambling Skills! </h2>
# <p> This one is for the gambling aficionados—the A.C. and Las Vegas lovers, listen up! </p>
# ...

# %%
plt.scatter(data['PSQI_AmtSleep'], data['Gambling_Task_Median_RT_Smaller'], color=['red','orange','yellow','green'])
plt.title("Does Sleeping Affect How You Gamble?", size='xx-large')

plt.ylabel('Median Score on Gambling Task')
plt.xlabel('Hours Slept')
plt.show()

# %%
# %%HTML
# <style>
#     body {background-color:#ffffff;background-repeat:no-repeat;background-position:top left;background-attachment:fixed;}
#     h2{text-align:center;font-family:Helvetica, serif;font-size:15px;font-style:normal;font-weight:normal;color:#000000;background-color:#FFFFFF;}
#     h3{text-align:left;font-family:Helvetica, sans-serif;color:#000000;background-color:#FFFFFF;}
#     p{text-align:left;font-family:Helvetica, serif;font-size:15px;font-style:normal;font-weight:normal;color:#000000;background-color:#FFFFFF;}
# </style>
# <h2> Don't Lose Your Marbles—Your Cognitive Alertness Might Peak At 30! </h2>
# <p> Every college classroom has made me a beleiver that your attention span might decrease with age (though scientists claim it's the opposite). The scientists have won this round.</p>
# <p> As you can see with the density plot below, subjects with the highest MMSE_Scores, an indicator of your cognitive alertness are between 28-30 years of age. </p>
# <p> Shockingly, college students are required to sit through 1 hour and 20 minutes of lectures, but subjects 24 and under tend to have the lowest MMSE_Scores. Next time your professor tells you to focus, blame it on your age! (I highly advise against doing this.) </p>
# <p> A <span style="font-weight:bold">density plot</span> seemed to fit the nature of this data the best. I wanted to showcase the misinformation about focus and attention there is in the academic and workplace environment. Using a density plot truly indicated the peaks of focus that come with a very short age range. This might give support for increased salaries in your late 20s and early 30s. Be sure to lock in a good contract before your marbles start to loosen up again.</p>
# Out:
# <style>
#     body {background-color:#ffffff;background-repeat:no-repeat;background-position:top left;background-attachment:fixed;}
#     h2{text-align:center;font-family:Helvetica, serif;font-size:15px;font-style:normal;font-weight:normal;color:#000000;background-color:#FFFFFF;}
#     h3{text-align:left;font-family:Helvetica, sans-serif;color:#000000;background-color:#FFFFFF;}
#     p{text-align:left;font-family:Helvetica, serif;font-size:15px;font-style:normal;font-weight:normal;color:#000000;background-color:#FFFFFF;}
# </style>
# <h2> Don't Lose Your Marbles—Your Cognitive Alertness Might Peak At 30! </h2>
# <p> Every college classroom has made me a beleiver that your attention span might decrease with age (though scientists claim it's the opposite). The scientists have won this round.</p>
# <p> As you can see with the density plot below, subjects with the highest MMSE_Scores, an indicator of your cognitive alertness are between 28-30 years of age. </p>
# ...

# %%
data.plot('Age','MMSE_Score', kind='density')

# %%
# %%HTML
# <style>
#     body {background-color:#ffffff;background-repeat:no-repeat;background-position:top left;background-attachment:fixed;}
#     h2{text-align:center;font-family:Helvetica, serif;font-size:15px;font-style:normal;font-weight:normal;color:#000000;background-color:#FFFFFF;}
#     h3{text-align:left;font-family:Helvetica, sans-serif;color:#000000;background-color:#FFFFFF;}
#     p{text-align:left;font-family:Helvetica, serif;font-size:15px;font-style:normal;font-weight:normal;color:#000000;background-color:#FFFFFF;}
# </style>
# <h2> How You Feel About The World Might Dictate How Much Control You Feel Over Yourself! </h2>
# <p> By utilizing a <span style="font-weight:bold">scatterplot</span>, I chose to highlight the correlation between a subject's Life Satisfaction Scale Score and his or her Self-Efficacy Rating. The data suggests that a higher life satisfaction score might correlate with a higher self-efficacy rating. This implies that what we see in the world does influence how we see ourselves. Fromn a psychological well-being perspective, this data is powerful. There are many people who see darkness and remorse in the world, but claim to not known of its origins. By showing that this could be a possible reason for otherewise inexplicable intrusive thoughts and negative outlook, it might open up conversation and cognitive restructuring. </p>
# <p> I wish to emphasize that I do not claim that there is a causation, but this information might serve to support research on cognitive processing and self-efficacy.</p>
# Out:
# <style>
#     body {background-color:#ffffff;background-repeat:no-repeat;background-position:top left;background-attachment:fixed;}
#     h2{text-align:center;font-family:Helvetica, serif;font-size:15px;font-style:normal;font-weight:normal;color:#000000;background-color:#FFFFFF;}
#     h3{text-align:left;font-family:Helvetica, sans-serif;color:#000000;background-color:#FFFFFF;}
#     p{text-align:left;font-family:Helvetica, serif;font-size:15px;font-style:normal;font-weight:normal;color:#000000;background-color:#FFFFFF;}
# </style>
# <h2> How You Feel About The World Might Dictate How Much Control You Feel Over Yourself! </h2>
# ...

# %%
plt.scatter(data['LifeSatisf_Unadj'], data['SelfEff_Unadj'], color=['white', 'red'])
plt.title("Does Your Worldview Affect Your Belief About Yourself?", size='xx-large')

plt.ylabel('Self-Efficacy Rating')
plt.xlabel('Life Satisfaction Scale Score')

plt.show()

# %%
# %%HTML
# <head>
# <h3>Future Implications</h3>
# <body>
# <p> The data visualizations I present to you are the tip of the iceberg. The visualizations of this data are nearly endless. The known benefit of mapping the human brain exists: alleviating and predicting disorders, expanding mental illness awareness, and incorporating such connections into an artifical agent. However, before this data achieves all of that, it still serves to tell us a story in the raw form. </p>
# <p> The range of topics this data can shed light on is evidenced by the visualizations above. </p>
#
# <p> For the final report, I will want to flesh out more visualizations, and possibly incorporate even more complex visualizations. In addition, I look forward to deciding which machine learning algorithm(s) I will choose to work with. </p>
# <p> Based on the nature of my data, I will choose a supervised machine learning algorithm. I am still debating whether I will implement binomial classification or multi-class classification of many possibilities within a single, or a regression, possibly an anomaly detection based on the number of outliers there were in the visualizations above. </p>
# <p> I did begin to look through the various machine learning algorhtms and which would be best suited to my dataset. I am interested in choosing a machine learning platform, which I am still debating (Anaconda, Apache Spark, etc.). This was a challenging stage, but I know there will be more challenges along the way and I look forward to handling them.</p>
# </body>
# </html>
# Out:
# <head>
# <h3>Future Implications</h3>
# <body>
# <p> The data visualizations I present to you are the tip of the iceberg. The visualizations of this data are nearly endless. The known benefit of mapping the human brain exists: alleviating and predicting disorders, expanding mental illness awareness, and incorporating such connections into an artifical agent. However, before this data achieves all of that, it still serves to tell us a story in the raw form. </p>
# <p> The range of topics this data can shed light on is evidenced by the visualizations above. </p>
#
# <p> For the final report, I will want to flesh out more visualizations, and possibly incorporate even more complex visualizations. In addition, I look forward to deciding which machine learning algorithm(s) I will choose to work with. </p>
# ...

# %% [raw]
# <script>
#   $(document).ready(function(){
#     $('div.prompt').hide();
#     $('div.back-to-top').hide();
#     $('nav#menubar').hide();
#     $('.breadcrumb').hide();
#     $('.hidden-print').hide();
#   });
# </script>
#
# <footer id="attribution" style="float:right; color:#999; background:#fff;">
# Created with Jupyter, delivered by Fastly, rendered by Rackspace.
# </footer>
